# %% [markdown]
# # Feature Engineering
#
# ## Amaç
#
# Datada olan farklı featureleri içeri eklemek veya türetmek.

# %%
import pandas as pd
import numpy as np
from src.config import *
from src.data_loader import create_sample_dataset

if not TRAIN_FILE.exists():
    df = create_sample_dataset(n_samples=15000, save_path=TRAIN_FILE)
else:
    df = pd.read_csv(TRAIN_FILE)

# Feature engineering işlemleri burada yapılacak
